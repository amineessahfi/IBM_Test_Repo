# %% [markdown]
# ## My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Amine__ __Essahfi__ <br> Data Scientist.

# %% [markdown]
# *Data Science is the sexiest job of the 21st century. I would love to embark on a journey in this field considering all scenarios due to its importance in this day and  age , in addition to being passionate about it.*

# %% [markdown]
# #### My code snippet below prints "Hello Data Science!"

# %%
print("Hello Data Science!")
# Out:
# Hello Data Science!

# %% [markdown]
# ***
# <ul>
#     <li>One</li>
#     <li>Two</li>
#     <li>Three</li>
# </ul>
#
# <ol>
#     <li>One</li>
#     <li>Two</li>
#     <li>Three</li>
# </ol>
